# %% [markdown]
# # Imports

# %%
import json
import pandas as pd
import matplotlib as mpl
from matplotlib import pyplot as plt
from sklearn import preprocessing as preproc
from sklearn.decomposition import PCA
import numpy as np

from scipy import stats

# https://stackoverflow.com/questions/52285104/3d-scatterplots-with-hue-colormap-and-legend
from mpl_toolkits.mplot3d import Axes3D

import seaborn as sns

try:
  from google.colab import drive
  drive.mount('/content/drive')

  COLAB = True
except ModuleNotFoundError:
  COLAB = False

from matplotlib import colors
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

top = cm.get_cmap('Blues_r', 128)
bottom = cm.get_cmap('Blues', 128)
newcolors = np.vstack((top(np.linspace(0, 1, 128)),
                       bottom(np.linspace(0, 1, 128))))
cm_blue_grad = ListedColormap(newcolors, name='CustomBlue')

cm_bool = sns.color_palette("blend:#31bdff,white", as_cmap=True)


# %matplotlib inline
# Out:
# /tmp/ipykernel_390561/3615078541.py:28: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   top = cm.get_cmap('Blues_r', 128)
# /tmp/ipykernel_390561/3615078541.py:29: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   bottom = cm.get_cmap('Blues', 128)

# %% [markdown]
# # Load Data

# %%
df = pd.read_parquet("diabetic_data_cleaned.parquet")

# fix some types that parquet didn't get right
df["admission_type_id"] = df["admission_type_id"].astype("category")
df["discharge_disposition_id"] = df["discharge_disposition_id"].astype("category")
df["admission_source_id"] = df["admission_source_id"].astype("category")

# creating a new column to identify readmission, regardelss of the number of days
df["readmitted_any"] = df["readmitted"] == "NO"

TGT2 = "readmitted_any"

display(df.shape)
display(df.dtypes)
display(df.head(2).T)
# Out:
# (100244, 32)
# encounter_id                   int64
# patient_nbr                    int64
# race                        category
# gender                      category
# age                         category
# admission_type_id           category
# discharge_disposition_id    category
# admission_source_id         category
# time_in_hospital               int64
# num_lab_procedures             int64
# num_procedures                 int64
# num_medications                int64
# number_outpatient              int64
# number_emergency               int64
# number_inpatient               int64
# diag_1                      category
# diag_2                      category
# diag_3                      category
# number_diagnoses               int64
# metformin                   category
# repaglinide                 category
# glimepiride                 category
# glipizide                   category
# glyburide                   category
# pioglitazone                category
# rosiglitazone               category
# insulin                     category
# glyburide-metformin         category
# change                          bool
# diabetesMed                     bool
# readmitted                  category
# readmitted_any                  bool
# dtype: object
#                                   0                1
# encounter_id                 149190            64410
# patient_nbr                55629189         86047875
# race                      Caucasian  AfricanAmerican
# gender                       Female           Female
# age                         [10-20)          [20-30)
# admission_type_id                 1                1
# discharge_disposition_id          1                1
# admission_source_id               7                7
# time_in_hospital                  3                2
# num_lab_procedures               59               11
# num_procedures                    0                5
# num_medications                  18               13
# number_outpatient                 0                2
# number_emergency                  0                0
# number_inpatient                  0                1
# diag_1                          276              648
# diag_2                       250.01              250
# diag_3                          255              V27
# number_diagnoses                  9                6
# metformin                        No               No
# repaglinide                      No               No
# glimepiride                      No               No
# glipizide                        No           Steady
# glyburide                        No               No
# pioglitazone                     No               No
# rosiglitazone                    No               No
# insulin                          Up               No
# glyburide-metformin              No               No
# change                         True            False
# diabetesMed                    True             True
# readmitted                      >30               NO
# readmitted_any                False             True

# %%
with open("data_dictionary.json", "r") as f:
  data_info = json.load(f)

NUM_COLUMNS = data_info["Numeric Columns"]
ORD_COLUMNS = data_info["Ordinal Columns"]
NOM_COLUMNS = data_info["Nominal Columns"]
CAT_COLUMNS = ORD_COLUMNS + NOM_COLUMNS
TGT = data_info["Target"]

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Numeric Columns

# %% [markdown]
# ### Summary Statistics

# %%
df[NUM_COLUMNS].describe().T
# Out:
#                        count       mean        std  min   25%   50%   75%  \
# time_in_hospital    100244.0   4.420275   2.991273  1.0   2.0   4.0   6.0
# num_lab_procedures  100244.0  43.173716  19.691484  1.0  32.0  44.0  57.0
# num_procedures      100244.0   1.350275   1.710913  0.0   0.0   1.0   2.0
# num_medications     100244.0  16.117823   8.116424  1.0  11.0  15.0  20.0
# number_outpatient   100244.0   0.372561   1.274074  0.0   0.0   0.0   0.0
# number_emergency    100244.0   0.199014   0.933541  0.0   0.0   0.0   0.0
# number_inpatient    100244.0   0.639470   1.262773  0.0   0.0   0.0   1.0
# number_diagnoses    100244.0   7.497007   1.839537  3.0   6.0   8.0   9.0
#
#                       max
# time_in_hospital     14.0
# num_lab_procedures  132.0
# num_procedures        6.0
# num_medications      81.0
# number_outpatient    42.0
# number_emergency     76.0
# number_inpatient     21.0
# number_diagnoses     16.0

# %% [markdown]
# ### Plots

# %%
num_cols = 4

fig, axes = plt.subplots((len(NUM_COLUMNS) // num_cols), num_cols, figsize=(15, 6), constrained_layout=True)

fig.suptitle("Numerical columns - histograms", fontsize=10)

plot_nums = {
  'time_in_hospital' : { "bins": 10 },
  'num_lab_procedures' : { "bins": 30 },
  'num_procedures' : { "bins": 10 },
  'num_medications' : { "bins": 20 },
  'number_outpatient' : { "bins": 10, "log_scale": (True, False) },
  'number_emergency' : { "bins": 10, "log_scale": (True, False) },
  'number_inpatient' : { "bins": 15, "log_scale": (True, False) },
  'number_diagnoses' : { "bins": 10 }
}

for i, (col, kwargs) in enumerate(plot_nums.items()):
  ax=axes[i // num_cols, i % num_cols]
  ax.set_title(f"{col} histogram", fontsize=8)

  sns.histplot(df[col],
               bins=kwargs["bins"],
               ax=ax,
               log_scale=kwargs.get("log_scale", (False, False)))

# %% [markdown]
# ## Categorical columns

# %% [markdown]
# ### Summary Statistics

# %%
# sns.heatmap(chi2_results_pivot, annot=True, cmap="Blues", mask=chi2_results_pivot < 0.05, vmin=0, vmax=1)
#sns.heatmap(chi2_results_pivot, annot=True, cmap="Blues", vmin=0, vmax=1)

# display(chi2_results
#         .style
#         .set_caption("Chi2 test results - Categorical Columns vs Categorical Columns")
#         .background_gradient(axis=0, gmap=chi2_results["p-value < 0.05"], cmap=cm_bool))
df[CAT_COLUMNS].describe().T.sort_values(by="unique", ascending=False)
# Out:
#                            count unique        top   freq
# diag_3                    100244    789        250  11533
# diag_2                    100244    743        428   6657
# diag_1                    100244    715        428   6853
# discharge_disposition_id  100244     26          1  59005
# admission_source_id       100244     17          7  56799
# age                       100244     10    [70-80)  25898
# admission_type_id         100244      8          1  53232
# race                      100244      5  Caucasian  76744
# glyburide-metformin       100244      4         No  99549
# insulin                   100244      4         No  46802
# repaglinide               100244      4         No  98711
# rosiglitazone             100244      4         No  93941
# pioglitazone              100244      4         No  92999
# glyburide                 100244      4         No  89719
# glipizide                 100244      4         No  87682
# glimepiride               100244      4         No  95104
# metformin                 100244      4         No  80543
# gender                    100244      2     Female  53924
# change                    100244      2      False  53892
# diabetesMed               100244      2       True  77155

# %% [markdown]
# ### Plots

# %%
num_cols = 5

cols = [TGT] + CAT_COLUMNS

fig, axes = plt.subplots(len(cols) // num_cols + 1, num_cols, figsize=(20, 15), constrained_layout=True)

fig.suptitle("Categorical columns - barplots", fontsize=14)

CAT_MANY_CATEGORIES = []

VERBOSE = False

# display the number of unique values for each categorical column in cols
for i, col in enumerate(cols):
  if VERBOSE:
    print(df[col].value_counts().sort_values(), end="\n\n")

  ax=axes[i // num_cols, i % num_cols]
  ax.set_title(f"{col} histogram", fontsize=10)

  freq_table = df[col].value_counts().sort_index()
  
  x=freq_table.index.tolist()
  y=freq_table.values

  if freq_table.shape[0] > 20:
    ax.text(0.5,
            0.5,
            "Graph removed\nToo many categories",
            transform=ax.transAxes,
            horizontalalignment='center',
            verticalalignment='center',
            fontsize=8,
            color='red')
    CAT_MANY_CATEGORIES.append(col)
    continue

  #df[col].value_counts().sort_values().plot(kind="bar", ax=ax, rot=45, xlabel=None)
  p = sns.barplot(x=x, y=y, ax=ax)
  p.set_title(f"{col}", fontsize=10)
  p.set_xticks(x)
  p.set_xticklabels(x, rotation=80)
  p.set_xlabel(None)
  p.set_yscale("log")
  p.set_ylim(bottom=1, top=max(y) * 2)

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ## Numeric vs TGT

# %% [markdown]
# ### Plots

# %%
num_cols = 4

fig, axes = plt.subplots(len(NUM_COLUMNS) // num_cols, num_cols, figsize=(16, 8), constrained_layout=True)
    
fig.suptitle("Numerical columns vs target - boxplots", fontsize=16)

for i, col in enumerate(NUM_COLUMNS):
  ax=axes[i // num_cols, i % num_cols]
  ax.set_title(f"{col} vs {TGT}", fontsize=10)

  sns.boxplot(y=col, x=TGT, data=df, ax=ax)

# %% [markdown]
# ### Summary Statistics

# %%
anova_results = []
for col in NUM_COLUMNS:
    groups = df.groupby(TGT2, observed=False)[col].apply(np.array)
    f, p = stats.f_oneway(groups[0], groups[1])
    anova_results.append((col, f, p))

anova_results = pd.DataFrame(anova_results, columns=["Variable", "F", "p-value"])
anova_results["p-value < 0.05"] = anova_results["p-value"] < 0.05

display(anova_results
        .style
        .set_caption("ANOVA test results - Predicting Readmission vs No Readmission")
        .background_gradient(axis=0, gmap=anova_results["p-value < 0.05"], cmap=cm_bool, vmin=0, vmax=1))
# Out:
# /tmp/ipykernel_390561/798533659.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   f, p = stats.f_oneway(groups[0], groups[1])
# <style type="text/css">
# #T_c0b43_row0_col0, #T_c0b43_row0_col1, #T_c0b43_row0_col2, #T_c0b43_row0_col3, #T_c0b43_row1_col0, #T_c0b43_row1_col1, #T_c0b43_row1_col2, #T_c0b43_row1_col3, #T_c0b43_row2_col0, #T_c0b43_row2_col1, #T_c0b43_row2_col2, #T_c0b43_row2_col3, #T_c0b43_row3_col0, #T_c0b43_row3_col1, #T_c0b43_row3_col2, #T_c0b43_row3_col3, #T_c0b43_row4_col0, #T_c0b43_row4_col1, #T_c0b43_row4_col2, #T_c0b43_row4_col3, #T_c0b43_row5_col0, #T_c0b43_row5_col1, #T_c0b43_row5_col2, #T_c0b43_row5_col3, #T_c0b43_row6_col0, #T_c0b43_row6_col1, #T_c0b43_row6_col2, #T_c0b43_row6_col3, #T_c0b43_row7_col0, #T_c0b43_row7_col1, #T_c0b43_row7_col2, #T_c0b43_row7_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# </style>
# <table id="T_c0b43">
#   <caption>ANOVA test results - Predicting Readmission vs No Readmission</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0b43_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_c0b43_level0_col1" class="col_heading level0 col1" >F</th>
#       <th id="T_c0b43_level0_col2" class="col_heading level0 col2" >p-value</th>
#       <th id="T_c0b43_level0_col3" class="col_heading level0 col3" >p-value < 0.05</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0b43_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0b43_row0_col0" class="data row0 col0" >time_in_hospital</td>
#       <td id="T_c0b43_row0_col1" class="data row0 col1" >240.875195</td>
#       <td id="T_c0b43_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_c0b43_row0_col3" class="data row0 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c0b43_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c0b43_row1_col0" class="data row1 col0" >num_lab_procedures</td>
#       <td id="T_c0b43_row1_col1" class="data row1 col1" >143.479388</td>
#       <td id="T_c0b43_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_c0b43_row1_col3" class="data row1 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c0b43_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c0b43_row2_col0" class="data row2 col0" >num_procedures</td>
#       <td id="T_c0b43_row2_col1" class="data row2 col1" >220.530975</td>
#       <td id="T_c0b43_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_c0b43_row2_col3" class="data row2 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c0b43_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c0b43_row3_col0" class="data row3 col0" >num_medications</td>
#       <td id="T_c0b43_row3_col1" class="data row3 col1" >187.255839</td>
#       <td id="T_c0b43_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_c0b43_row3_col3" class="data row3 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c0b43_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c0b43_row4_col0" class="data row4 col0" >number_outpatient</td>
#       <td id="T_c0b43_row4_col1" class="data row4 col1" >665.949786</td>
#       <td id="T_c0b43_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_c0b43_row4_col3" class="data row4 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c0b43_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c0b43_row5_col0" class="data row5 col0" >number_emergency</td>
#       <td id="T_c0b43_row5_col1" class="data row5 col1" >1057.697011</td>
#       <td id="T_c0b43_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_c0b43_row5_col3" class="data row5 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c0b43_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c0b43_row6_col0" class="data row6 col0" >number_inpatient</td>
#       <td id="T_c0b43_row6_col1" class="data row6 col1" >4888.446000</td>
#       <td id="T_c0b43_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_c0b43_row6_col3" class="data row6 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c0b43_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c0b43_row7_col0" class="data row7 col0" >number_diagnoses</td>
#       <td id="T_c0b43_row7_col1" class="data row7 col1" >1165.465486</td>
#       <td id="T_c0b43_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_c0b43_row7_col3" class="data row7 col3" >True</td>
#     </tr>
#   </tbody>
# </table>

# %%
anova_results = []
for col in NUM_COLUMNS:
    groups = df.groupby(TGT, observed=False)[col].apply(np.array)
    f, p = stats.f_oneway(groups["<30"], groups[">30"])
    anova_results.append((col, f, p))

anova_results = pd.DataFrame(anova_results, columns=["Variable", "F", "p-value"])
anova_results["p-value < 0.05"] = anova_results["p-value"] < 0.05
display(anova_results
        .style
        .set_caption("ANOVA test results - Predicting <30 vs >30 days readmission")
        .background_gradient(axis=0, gmap=anova_results["p-value < 0.05"], cmap=cm_bool, vmin=0, vmax=1))
# Out:
# <style type="text/css">
# #T_220a4_row0_col0, #T_220a4_row0_col1, #T_220a4_row0_col2, #T_220a4_row0_col3, #T_220a4_row3_col0, #T_220a4_row3_col1, #T_220a4_row3_col2, #T_220a4_row3_col3, #T_220a4_row4_col0, #T_220a4_row4_col1, #T_220a4_row4_col2, #T_220a4_row4_col3, #T_220a4_row5_col0, #T_220a4_row5_col1, #T_220a4_row5_col2, #T_220a4_row5_col3, #T_220a4_row6_col0, #T_220a4_row6_col1, #T_220a4_row6_col2, #T_220a4_row6_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_220a4_row1_col0, #T_220a4_row1_col1, #T_220a4_row1_col2, #T_220a4_row1_col3, #T_220a4_row2_col0, #T_220a4_row2_col1, #T_220a4_row2_col2, #T_220a4_row2_col3, #T_220a4_row7_col0, #T_220a4_row7_col1, #T_220a4_row7_col2, #T_220a4_row7_col3 {
#   background-color: #31bdff;
#   color: #000000;
# }
# </style>
# <table id="T_220a4">
#   <caption>ANOVA test results - Predicting <30 vs >30 days readmission</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_220a4_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_220a4_level0_col1" class="col_heading level0 col1" >F</th>
#       <th id="T_220a4_level0_col2" class="col_heading level0 col2" >p-value</th>
#       <th id="T_220a4_level0_col3" class="col_heading level0 col3" >p-value < 0.05</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_220a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_220a4_row0_col0" class="data row0 col0" >time_in_hospital</td>
#       <td id="T_220a4_row0_col1" class="data row0 col1" >69.424063</td>
#       <td id="T_220a4_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_220a4_row0_col3" class="data row0 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_220a4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_220a4_row1_col0" class="data row1 col0" >num_lab_procedures</td>
#       <td id="T_220a4_row1_col1" class="data row1 col1" >3.244503</td>
#       <td id="T_220a4_row1_col2" class="data row1 col2" >0.071670</td>
#       <td id="T_220a4_row1_col3" class="data row1 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_220a4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_220a4_row2_col0" class="data row2 col0" >num_procedures</td>
#       <td id="T_220a4_row2_col1" class="data row2 col1" >2.894656</td>
#       <td id="T_220a4_row2_col2" class="data row2 col2" >0.088880</td>
#       <td id="T_220a4_row2_col3" class="data row2 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_220a4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_220a4_row3_col0" class="data row3 col0" >num_medications</td>
#       <td id="T_220a4_row3_col1" class="data row3 col1" >52.236582</td>
#       <td id="T_220a4_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_220a4_row3_col3" class="data row3 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_220a4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_220a4_row4_col0" class="data row4 col0" >number_outpatient</td>
#       <td id="T_220a4_row4_col1" class="data row4 col1" >13.722661</td>
#       <td id="T_220a4_row4_col2" class="data row4 col2" >0.000212</td>
#       <td id="T_220a4_row4_col3" class="data row4 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_220a4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_220a4_row5_col0" class="data row5 col0" >number_emergency</td>
#       <td id="T_220a4_row5_col1" class="data row5 col1" >30.208933</td>
#       <td id="T_220a4_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_220a4_row5_col3" class="data row5 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_220a4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_220a4_row6_col0" class="data row6 col0" >number_inpatient</td>
#       <td id="T_220a4_row6_col1" class="data row6 col1" >515.330482</td>
#       <td id="T_220a4_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_220a4_row6_col3" class="data row6 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_220a4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_220a4_row7_col0" class="data row7 col0" >number_diagnoses</td>
#       <td id="T_220a4_row7_col1" class="data row7 col1" >3.504548</td>
#       <td id="T_220a4_row7_col2" class="data row7 col2" >0.061207</td>
#       <td id="T_220a4_row7_col3" class="data row7 col3" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
anova_results = []
for col in NUM_COLUMNS:
    groups = df.groupby(TGT, observed=False)[col].apply(np.array)
    f, p = stats.f_oneway(groups["NO"], groups[">30"])
    anova_results.append((col, f, p))

anova_results = pd.DataFrame(anova_results, columns=["Variable", "F", "p-value"])
anova_results["p-value < 0.05"] = anova_results["p-value"] < 0.05
display(anova_results
        .style
        .set_caption("ANOVA test results - Predicting NO readmission vs >30 days readmission")
        .background_gradient(axis=0, gmap=anova_results["p-value < 0.05"], cmap=cm_bool, vmin=0, vmax=1))
# Out:
# <style type="text/css">
# #T_d9554_row0_col0, #T_d9554_row0_col1, #T_d9554_row0_col2, #T_d9554_row0_col3, #T_d9554_row1_col0, #T_d9554_row1_col1, #T_d9554_row1_col2, #T_d9554_row1_col3, #T_d9554_row2_col0, #T_d9554_row2_col1, #T_d9554_row2_col2, #T_d9554_row2_col3, #T_d9554_row3_col0, #T_d9554_row3_col1, #T_d9554_row3_col2, #T_d9554_row3_col3, #T_d9554_row4_col0, #T_d9554_row4_col1, #T_d9554_row4_col2, #T_d9554_row4_col3, #T_d9554_row5_col0, #T_d9554_row5_col1, #T_d9554_row5_col2, #T_d9554_row5_col3, #T_d9554_row6_col0, #T_d9554_row6_col1, #T_d9554_row6_col2, #T_d9554_row6_col3, #T_d9554_row7_col0, #T_d9554_row7_col1, #T_d9554_row7_col2, #T_d9554_row7_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# </style>
# <table id="T_d9554">
#   <caption>ANOVA test results - Predicting NO readmission vs >30 days readmission</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9554_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_d9554_level0_col1" class="col_heading level0 col1" >F</th>
#       <th id="T_d9554_level0_col2" class="col_heading level0 col2" >p-value</th>
#       <th id="T_d9554_level0_col3" class="col_heading level0 col3" >p-value < 0.05</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9554_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9554_row0_col0" class="data row0 col0" >time_in_hospital</td>
#       <td id="T_d9554_row0_col1" class="data row0 col1" >124.527133</td>
#       <td id="T_d9554_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_d9554_row0_col3" class="data row0 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d9554_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d9554_row1_col0" class="data row1 col0" >num_lab_procedures</td>
#       <td id="T_d9554_row1_col1" class="data row1 col1" >107.252734</td>
#       <td id="T_d9554_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_d9554_row1_col3" class="data row1 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d9554_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d9554_row2_col0" class="data row2 col0" >num_procedures</td>
#       <td id="T_d9554_row2_col1" class="data row2 col1" >203.944776</td>
#       <td id="T_d9554_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_d9554_row2_col3" class="data row2 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d9554_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d9554_row3_col0" class="data row3 col0" >num_medications</td>
#       <td id="T_d9554_row3_col1" class="data row3 col1" >100.083972</td>
#       <td id="T_d9554_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_d9554_row3_col3" class="data row3 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d9554_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d9554_row4_col0" class="data row4 col0" >number_outpatient</td>
#       <td id="T_d9554_row4_col1" class="data row4 col1" >655.754299</td>
#       <td id="T_d9554_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_d9554_row4_col3" class="data row4 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d9554_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d9554_row5_col0" class="data row5 col0" >number_emergency</td>
#       <td id="T_d9554_row5_col1" class="data row5 col1" >872.985235</td>
#       <td id="T_d9554_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_d9554_row5_col3" class="data row5 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d9554_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d9554_row6_col0" class="data row6 col0" >number_inpatient</td>
#       <td id="T_d9554_row6_col1" class="data row6 col1" >3581.999920</td>
#       <td id="T_d9554_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_d9554_row6_col3" class="data row6 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d9554_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d9554_row7_col0" class="data row7 col0" >number_diagnoses</td>
#       <td id="T_d9554_row7_col1" class="data row7 col1" >937.603694</td>
#       <td id="T_d9554_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_d9554_row7_col3" class="data row7 col3" >True</td>
#     </tr>
#   </tbody>
# </table>

# %%
anova_results = []
for col in NUM_COLUMNS:
    groups = df.groupby(TGT, observed=False)[col].apply(np.array)
    f, p = stats.f_oneway(groups["NO"], groups["<30"])
    anova_results.append((col, f, p))

anova_results = pd.DataFrame(anova_results, columns=["Variable", "F", "p-value"])
anova_results["p-value < 0.05"] = anova_results["p-value"] < 0.05

display(anova_results
        .style
        .set_caption("ANOVA test results - Predicting NO readmission vs <30 days readmission")
        .background_gradient(axis=0, gmap=anova_results["p-value < 0.05"], cmap=cm_bool, vmin=0, vmax=1))
# Out:
# <style type="text/css">
# #T_64625_row0_col0, #T_64625_row0_col1, #T_64625_row0_col2, #T_64625_row0_col3, #T_64625_row1_col0, #T_64625_row1_col1, #T_64625_row1_col2, #T_64625_row1_col3, #T_64625_row2_col0, #T_64625_row2_col1, #T_64625_row2_col2, #T_64625_row2_col3, #T_64625_row3_col0, #T_64625_row3_col1, #T_64625_row3_col2, #T_64625_row3_col3, #T_64625_row4_col0, #T_64625_row4_col1, #T_64625_row4_col2, #T_64625_row4_col3, #T_64625_row5_col0, #T_64625_row5_col1, #T_64625_row5_col2, #T_64625_row5_col3, #T_64625_row6_col0, #T_64625_row6_col1, #T_64625_row6_col2, #T_64625_row6_col3, #T_64625_row7_col0, #T_64625_row7_col1, #T_64625_row7_col2, #T_64625_row7_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# </style>
# <table id="T_64625">
#   <caption>ANOVA test results - Predicting NO readmission vs <30 days readmission</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64625_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_64625_level0_col1" class="col_heading level0 col1" >F</th>
#       <th id="T_64625_level0_col2" class="col_heading level0 col2" >p-value</th>
#       <th id="T_64625_level0_col3" class="col_heading level0 col3" >p-value < 0.05</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64625_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64625_row0_col0" class="data row0 col0" >time_in_hospital</td>
#       <td id="T_64625_row0_col1" class="data row0 col1" >260.123401</td>
#       <td id="T_64625_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_64625_row0_col3" class="data row0 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_64625_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_64625_row1_col0" class="data row1 col0" >num_lab_procedures</td>
#       <td id="T_64625_row1_col1" class="data row1 col1" >75.843887</td>
#       <td id="T_64625_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_64625_row1_col3" class="data row1 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_64625_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_64625_row2_col0" class="data row2 col0" >num_procedures</td>
#       <td id="T_64625_row2_col1" class="data row2 col1" >58.894324</td>
#       <td id="T_64625_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_64625_row2_col3" class="data row2 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_64625_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_64625_row3_col0" class="data row3 col0" >num_medications</td>
#       <td id="T_64625_row3_col1" class="data row3 col1" >179.434816</td>
#       <td id="T_64625_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_64625_row3_col3" class="data row3 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_64625_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_64625_row4_col0" class="data row4 col0" >number_outpatient</td>
#       <td id="T_64625_row4_col1" class="data row4 col1" >206.257080</td>
#       <td id="T_64625_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_64625_row4_col3" class="data row4 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_64625_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_64625_row5_col0" class="data row5 col0" >number_emergency</td>
#       <td id="T_64625_row5_col1" class="data row5 col1" >1024.224202</td>
#       <td id="T_64625_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_64625_row5_col3" class="data row5 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_64625_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_64625_row6_col0" class="data row6 col0" >number_inpatient</td>
#       <td id="T_64625_row6_col1" class="data row6 col1" >5075.576664</td>
#       <td id="T_64625_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_64625_row6_col3" class="data row6 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_64625_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_64625_row7_col0" class="data row7 col0" >number_diagnoses</td>
#       <td id="T_64625_row7_col1" class="data row7 col1" >470.063575</td>
#       <td id="T_64625_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_64625_row7_col3" class="data row7 col3" >True</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Correlation

# %%
corr = df[NUM_COLUMNS].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap=cm_blue_grad, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %% [markdown]
# The conclusion here is, all the numerical columns are statistically significant to predict the target variable, though num_lab_procedures, num_procedures and number_diagnoses presented a high p-value to explain >30 and <30 days readmission.

# %% [markdown]
# ## Categorical vs TGT

# %% [markdown]
# ### Plots

# %%
# stack bar plots for categorical variables against the target - maybe replot this in R using mosaic is a better idea

num_cols = 4

fig, axes = plt.subplots(len(CAT_COLUMNS) // num_cols + 1, num_cols, figsize=(20, 20), constrained_layout=True)

fig.suptitle("Categorical columns vs target - mosaic plots", fontsize=16)

for i, col in enumerate(CAT_COLUMNS):
  ax=axes[i // num_cols, i % num_cols]
  ax.set_title(f"{col} vs {TGT}", fontsize=10)

  freq_table = df[col].value_counts().sort_index()
  if freq_table.shape[0] > 20:
    ax.text(0.5,
            0.5,
            "Graph removed\nToo many categories",
            transform=ax.transAxes,
            horizontalalignment='center',
            verticalalignment='center',
            fontsize=8,
            color='red')
    CAT_MANY_CATEGORIES.append(col)
    continue

  mosaic = pd.crosstab(df[col], df[TGT], normalize="index")
  mosaic.plot(kind="bar", stacked=True, ax=ax)

# %% [markdown]
# ### Summary Statistics

# %%
# running chi2 tests for all categorical variables against the target
chi2_results = []

for col in CAT_COLUMNS:
    cont_table = pd.crosstab(df[col], df[TGT])
    chi2, p, dof, expected = stats.chi2_contingency(cont_table)
    chi2_results.append((col, chi2, p))

chi2_results = pd.DataFrame(chi2_results, columns=["Variable", "Chi2", "p-value"])
chi2_results["p-value < 0.05"] = chi2_results["p-value"] < 0.05
display(chi2_results
        .style
        .set_caption("Chi2 test results - Categorical Columns vs TGT with <30 days, >30 days and NO readmission")
        .background_gradient(axis=0, gmap=chi2_results["p-value < 0.05"], cmap=cm_bool, vmin=0, vmax=1))
# Out:
# <style type="text/css">
# #T_6c30b_row0_col0, #T_6c30b_row0_col1, #T_6c30b_row0_col2, #T_6c30b_row0_col3, #T_6c30b_row1_col0, #T_6c30b_row1_col1, #T_6c30b_row1_col2, #T_6c30b_row1_col3, #T_6c30b_row2_col0, #T_6c30b_row2_col1, #T_6c30b_row2_col2, #T_6c30b_row2_col3, #T_6c30b_row3_col0, #T_6c30b_row3_col1, #T_6c30b_row3_col2, #T_6c30b_row3_col3, #T_6c30b_row5_col0, #T_6c30b_row5_col1, #T_6c30b_row5_col2, #T_6c30b_row5_col3, #T_6c30b_row6_col0, #T_6c30b_row6_col1, #T_6c30b_row6_col2, #T_6c30b_row6_col3, #T_6c30b_row7_col0, #T_6c30b_row7_col1, #T_6c30b_row7_col2, #T_6c30b_row7_col3, #T_6c30b_row9_col0, #T_6c30b_row9_col1, #T_6c30b_row9_col2, #T_6c30b_row9_col3, #T_6c30b_row10_col0, #T_6c30b_row10_col1, #T_6c30b_row10_col2, #T_6c30b_row10_col3, #T_6c30b_row11_col0, #T_6c30b_row11_col1, #T_6c30b_row11_col2, #T_6c30b_row11_col3, #T_6c30b_row12_col0, #T_6c30b_row12_col1, #T_6c30b_row12_col2, #T_6c30b_row12_col3, #T_6c30b_row13_col0, #T_6c30b_row13_col1, #T_6c30b_row13_col2, #T_6c30b_row13_col3, #T_6c30b_row14_col0, #T_6c30b_row14_col1, #T_6c30b_row14_col2, #T_6c30b_row14_col3, #T_6c30b_row15_col0, #T_6c30b_row15_col1, #T_6c30b_row15_col2, #T_6c30b_row15_col3, #T_6c30b_row16_col0, #T_6c30b_row16_col1, #T_6c30b_row16_col2, #T_6c30b_row16_col3, #T_6c30b_row17_col0, #T_6c30b_row17_col1, #T_6c30b_row17_col2, #T_6c30b_row17_col3, #T_6c30b_row18_col0, #T_6c30b_row18_col1, #T_6c30b_row18_col2, #T_6c30b_row18_col3, #T_6c30b_row19_col0, #T_6c30b_row19_col1, #T_6c30b_row19_col2, #T_6c30b_row19_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_6c30b_row4_col0, #T_6c30b_row4_col1, #T_6c30b_row4_col2, #T_6c30b_row4_col3, #T_6c30b_row8_col0, #T_6c30b_row8_col1, #T_6c30b_row8_col2, #T_6c30b_row8_col3 {
#   background-color: #31bdff;
#   color: #000000;
# }
# </style>
# <table id="T_6c30b">
#   <caption>Chi2 test results - Categorical Columns vs TGT with <30 days, >30 days and NO readmission</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c30b_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_6c30b_level0_col1" class="col_heading level0 col1" >Chi2</th>
#       <th id="T_6c30b_level0_col2" class="col_heading level0 col2" >p-value</th>
#       <th id="T_6c30b_level0_col3" class="col_heading level0 col3" >p-value < 0.05</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c30b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c30b_row0_col0" class="data row0 col0" >metformin</td>
#       <td id="T_6c30b_row0_col1" class="data row0 col1" >102.743633</td>
#       <td id="T_6c30b_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_6c30b_row0_col3" class="data row0 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c30b_row1_col0" class="data row1 col0" >repaglinide</td>
#       <td id="T_6c30b_row1_col1" class="data row1 col1" >56.755370</td>
#       <td id="T_6c30b_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_6c30b_row1_col3" class="data row1 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6c30b_row2_col0" class="data row2 col0" >glimepiride</td>
#       <td id="T_6c30b_row2_col1" class="data row2 col1" >17.188609</td>
#       <td id="T_6c30b_row2_col2" class="data row2 col2" >0.008615</td>
#       <td id="T_6c30b_row2_col3" class="data row2 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6c30b_row3_col0" class="data row3 col0" >glipizide</td>
#       <td id="T_6c30b_row3_col1" class="data row3 col1" >50.389089</td>
#       <td id="T_6c30b_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_6c30b_row3_col3" class="data row3 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6c30b_row4_col0" class="data row4 col0" >glyburide</td>
#       <td id="T_6c30b_row4_col1" class="data row4 col1" >10.158357</td>
#       <td id="T_6c30b_row4_col2" class="data row4 col2" >0.118140</td>
#       <td id="T_6c30b_row4_col3" class="data row4 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6c30b_row5_col0" class="data row5 col0" >pioglitazone</td>
#       <td id="T_6c30b_row5_col1" class="data row5 col1" >29.924266</td>
#       <td id="T_6c30b_row5_col2" class="data row5 col2" >0.000041</td>
#       <td id="T_6c30b_row5_col3" class="data row5 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6c30b_row6_col0" class="data row6 col0" >rosiglitazone</td>
#       <td id="T_6c30b_row6_col1" class="data row6 col1" >42.529923</td>
#       <td id="T_6c30b_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_6c30b_row6_col3" class="data row6 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6c30b_row7_col0" class="data row7 col0" >insulin</td>
#       <td id="T_6c30b_row7_col1" class="data row7 col1" >494.333077</td>
#       <td id="T_6c30b_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_6c30b_row7_col3" class="data row7 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6c30b_row8_col0" class="data row8 col0" >glyburide-metformin</td>
#       <td id="T_6c30b_row8_col1" class="data row8 col1" >8.551827</td>
#       <td id="T_6c30b_row8_col2" class="data row8 col2" >0.200396</td>
#       <td id="T_6c30b_row8_col3" class="data row8 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6c30b_row9_col0" class="data row9 col0" >age</td>
#       <td id="T_6c30b_row9_col1" class="data row9 col1" >240.449923</td>
#       <td id="T_6c30b_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_6c30b_row9_col3" class="data row9 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6c30b_row10_col0" class="data row10 col0" >race</td>
#       <td id="T_6c30b_row10_col1" class="data row10 col1" >86.815994</td>
#       <td id="T_6c30b_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_6c30b_row10_col3" class="data row10 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6c30b_row11_col0" class="data row11 col0" >gender</td>
#       <td id="T_6c30b_row11_col1" class="data row11 col1" >32.108913</td>
#       <td id="T_6c30b_row11_col2" class="data row11 col2" >0.000000</td>
#       <td id="T_6c30b_row11_col3" class="data row11 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6c30b_row12_col0" class="data row12 col0" >diag_1</td>
#       <td id="T_6c30b_row12_col1" class="data row12 col1" >4842.681757</td>
#       <td id="T_6c30b_row12_col2" class="data row12 col2" >0.000000</td>
#       <td id="T_6c30b_row12_col3" class="data row12 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6c30b_row13_col0" class="data row13 col0" >diag_2</td>
#       <td id="T_6c30b_row13_col1" class="data row13 col1" >3897.163399</td>
#       <td id="T_6c30b_row13_col2" class="data row13 col2" >0.000000</td>
#       <td id="T_6c30b_row13_col3" class="data row13 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6c30b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6c30b_row14_col0" class="data row14 col0" >diag_3</td>
#       <td id="T_6c30b_row14_col1" class="data row14 col1" >3780.854742</td>
#       <td id="T_6c30b_row14_col2" class="data row14 col2" >0.000000</td>
#       <td id="T_6c30b_row14_col3" class="data row1

# %%
# running chi2 tests for all categorical variables against the target
chi2_results = []

for col in CAT_COLUMNS:
    cont_table = pd.crosstab(df[col], df[TGT2])
    chi2, p, dof, expected = stats.chi2_contingency(cont_table)
    chi2_results.append((col, chi2, p))

chi2_results = pd.DataFrame(chi2_results, columns=["Variable", "Chi2", "p-value"])
chi2_results["p-value < 0.05"] = chi2_results["p-value"] < 0.05
display(chi2_results
        .style
        .set_caption("Chi2 test results - Categorical Columns vs readmission / No Readmission")
        .background_gradient(axis=0, gmap=chi2_results["p-value < 0.05"], cmap=cm_bool))
# Out:
# <style type="text/css">
# #T_c732b_row0_col0, #T_c732b_row0_col1, #T_c732b_row0_col2, #T_c732b_row0_col3, #T_c732b_row1_col0, #T_c732b_row1_col1, #T_c732b_row1_col2, #T_c732b_row1_col3, #T_c732b_row3_col0, #T_c732b_row3_col1, #T_c732b_row3_col2, #T_c732b_row3_col3, #T_c732b_row5_col0, #T_c732b_row5_col1, #T_c732b_row5_col2, #T_c732b_row5_col3, #T_c732b_row6_col0, #T_c732b_row6_col1, #T_c732b_row6_col2, #T_c732b_row6_col3, #T_c732b_row7_col0, #T_c732b_row7_col1, #T_c732b_row7_col2, #T_c732b_row7_col3, #T_c732b_row9_col0, #T_c732b_row9_col1, #T_c732b_row9_col2, #T_c732b_row9_col3, #T_c732b_row10_col0, #T_c732b_row10_col1, #T_c732b_row10_col2, #T_c732b_row10_col3, #T_c732b_row11_col0, #T_c732b_row11_col1, #T_c732b_row11_col2, #T_c732b_row11_col3, #T_c732b_row12_col0, #T_c732b_row12_col1, #T_c732b_row12_col2, #T_c732b_row12_col3, #T_c732b_row13_col0, #T_c732b_row13_col1, #T_c732b_row13_col2, #T_c732b_row13_col3, #T_c732b_row14_col0, #T_c732b_row14_col1, #T_c732b_row14_col2, #T_c732b_row14_col3, #T_c732b_row15_col0, #T_c732b_row15_col1, #T_c732b_row15_col2, #T_c732b_row15_col3, #T_c732b_row16_col0, #T_c732b_row16_col1, #T_c732b_row16_col2, #T_c732b_row16_col3, #T_c732b_row17_col0, #T_c732b_row17_col1, #T_c732b_row17_col2, #T_c732b_row17_col3, #T_c732b_row18_col0, #T_c732b_row18_col1, #T_c732b_row18_col2, #T_c732b_row18_col3, #T_c732b_row19_col0, #T_c732b_row19_col1, #T_c732b_row19_col2, #T_c732b_row19_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_c732b_row2_col0, #T_c732b_row2_col1, #T_c732b_row2_col2, #T_c732b_row2_col3, #T_c732b_row4_col0, #T_c732b_row4_col1, #T_c732b_row4_col2, #T_c732b_row4_col3, #T_c732b_row8_col0, #T_c732b_row8_col1, #T_c732b_row8_col2, #T_c732b_row8_col3 {
#   background-color: #31bdff;
#   color: #000000;
# }
# </style>
# <table id="T_c732b">
#   <caption>Chi2 test results - Categorical Columns vs readmission / No Readmission</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c732b_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_c732b_level0_col1" class="col_heading level0 col1" >Chi2</th>
#       <th id="T_c732b_level0_col2" class="col_heading level0 col2" >p-value</th>
#       <th id="T_c732b_level0_col3" class="col_heading level0 col3" >p-value < 0.05</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c732b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c732b_row0_col0" class="data row0 col0" >metformin</td>
#       <td id="T_c732b_row0_col1" class="data row0 col1" >81.944038</td>
#       <td id="T_c732b_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_c732b_row0_col3" class="data row0 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c732b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c732b_row1_col0" class="data row1 col0" >repaglinide</td>
#       <td id="T_c732b_row1_col1" class="data row1 col1" >49.613944</td>
#       <td id="T_c732b_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_c732b_row1_col3" class="data row1 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c732b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c732b_row2_col0" class="data row2 col0" >glimepiride</td>
#       <td id="T_c732b_row2_col1" class="data row2 col1" >4.077952</td>
#       <td id="T_c732b_row2_col2" class="data row2 col2" >0.253169</td>
#       <td id="T_c732b_row2_col3" class="data row2 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c732b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c732b_row3_col0" class="data row3 col0" >glipizide</td>
#       <td id="T_c732b_row3_col1" class="data row3 col1" >41.558298</td>
#       <td id="T_c732b_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_c732b_row3_col3" class="data row3 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c732b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c732b_row4_col0" class="data row4 col0" >glyburide</td>
#       <td id="T_c732b_row4_col1" class="data row4 col1" >4.400639</td>
#       <td id="T_c732b_row4_col2" class="data row4 col2" >0.221326</td>
#       <td id="T_c732b_row4_col3" class="data row4 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c732b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c732b_row5_col0" class="data row5 col0" >pioglitazone</td>
#       <td id="T_c732b_row5_col1" class="data row5 col1" >15.934413</td>
#       <td id="T_c732b_row5_col2" class="data row5 col2" >0.001170</td>
#       <td id="T_c732b_row5_col3" class="data row5 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c732b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c732b_row6_col0" class="data row6 col0" >rosiglitazone</td>
#       <td id="T_c732b_row6_col1" class="data row6 col1" >28.365380</td>
#       <td id="T_c732b_row6_col2" class="data row6 col2" >0.000003</td>
#       <td id="T_c732b_row6_col3" class="data row6 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c732b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c732b_row7_col0" class="data row7 col0" >insulin</td>
#       <td id="T_c732b_row7_col1" class="data row7 col1" >455.110870</td>
#       <td id="T_c732b_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_c732b_row7_col3" class="data row7 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c732b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c732b_row8_col0" class="data row8 col0" >glyburide-metformin</td>
#       <td id="T_c732b_row8_col1" class="data row8 col1" >7.066540</td>
#       <td id="T_c732b_row8_col2" class="data row8 col2" >0.069807</td>
#       <td id="T_c732b_row8_col3" class="data row8 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c732b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c732b_row9_col0" class="data row9 col0" >age</td>
#       <td id="T_c732b_row9_col1" class="data row9 col1" >180.887477</td>
#       <td id="T_c732b_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_c732b_row9_col3" class="data row9 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c732b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c732b_row10_col0" class="data row10 col0" >race</td>
#       <td id="T_c732b_row10_col1" class="data row10 col1" >83.148562</td>
#       <td id="T_c732b_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_c732b_row10_col3" class="data row10 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c732b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c732b_row11_col0" class="data row11 col0" >gender</td>
#       <td id="T_c732b_row11_col1" class="data row11 col1" >30.025186</td>
#       <td id="T_c732b_row11_col2" class="data row11 col2" >0.000000</td>
#       <td id="T_c732b_row11_col3" class="data row11 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c732b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c732b_row12_col0" class="data row12 col0" >diag_1</td>
#       <td id="T_c732b_row12_col1" class="data row12 col1" >3463.251914</td>
#       <td id="T_c732b_row12_col2" class="data row12 col2" >0.000000</td>
#       <td id="T_c732b_row12_col3" class="data row12 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c732b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c732b_row13_col0" class="data row13 col0" >diag_2</td>
#       <td id="T_c732b_row13_col1" class="data row13 col1" >2906.842814</td>
#       <td id="T_c732b_row13_col2" class="data row13 col2" >0.000000</td>
#       <td id="T_c732b_row13_col3" class="data row13 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c732b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c732b_row14_col0" class="data row14 col0" >diag_3</td>
#       <td id="T_c732b_row14_col1" class="data row14 col1" >2713.155302</td>
#       <td id="T_c732b_row14_col2" class="data row14 col2" >0.000000</td>
#       <td id="T_c732b_row14_col3" class="data row14 col3" >True</td>

# %% [markdown]
# #### chi-squared test among only the categorical variables

# %%
# chi-squared test for the categorical variables 2 by 2
chi2_results = []

for col1 in CAT_COLUMNS:
  for col2 in CAT_COLUMNS:
    cont_table = pd.crosstab(df[col1], df[col2])
    chi2, p, dof, expected = stats.chi2_contingency(cont_table)
    chi2_results.append((col1, col2, chi2, p))

chi2_results = pd.DataFrame(chi2_results, columns=["Variable1", "Variable2", "Chi2", "p-value"])
chi2_results["p-value < 0.05"] = chi2_results["p-value"] < 0.05

# pivor this chi2_results dataframe to create a heatmap with the p-values
chi2_results_pivot = chi2_results.pivot(index="Variable1", columns="Variable2", values="p-value")
chi2_results_pivot = chi2_results_pivot.round(3)

plt.figure(figsize=(14, 10))
# add a title
plt.title("Chi2 test results (p-values greater than .05) - Categorical Columns vs Categorical Columns")

# put a grid on the heatmap
sns.heatmap(chi2_results_pivot, annot=True, cmap="Blues", mask=chi2_results_pivot < 0.05, vmin=0, vmax=1, linewidths=.1, linecolor="#baccde");

# %% [markdown]
# # Conclusions
#
# From the statistics summary and graphical analysis EDA, some points to highlight:
#
# - All numerical columns might be relevant (though some small correlations, nothing to be concerned)
# - num_lab_procedures, num_procedures, and number_diagnosis might have low predictive power to predict the target.
# - Many of the categorical might be useful, though from the EDA, we must highlight that there is a small dependency from glyburide and glyburide-metformin to target, which may be connected to a low importance value of them in the prediction. The same happens with glimepiride, but in a lower scale.
# - Finally, the last heatmap shows that some pairs of categorical variables are not independent (they are somehow connected), and this might show that if we get one, we can avoid taking the other, avoiding irrelevant features. For instance, diag3 and glimepiride demonstrated a high level of association (p-value=1), thus, we might be inclined to take one of them.
#
# From the EDA, I did not remove any feature, we might remove during the training.
